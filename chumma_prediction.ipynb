# %%
import pandas as pd

df = pd.read_csv("dummy.txt", delimiter = "  ")
# Out:
# C:\Users\Swaroop\AppData\Local\Temp\ipykernel_21540\4165197501.py:3: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   df = pd.read_csv("dummy.txt", delimiter = "  ")

# %%
import matplotlib.pyplot as plt
plt.plot(df[[' 165']])

# %%
import pandas as pd

pd.read_csv('solar_dummy.txt', delimiter ="  ")
